# %%
import pandas as pd

orders_df = pd.read_csv("../Python_Analysis/data/orders.csv")
customer_metrics = pd.read_csv("../Python_Analysis/data/orders.csv")

orders_df.to_csv(
    "../PowerBI_Dashboard/orders_analysis.csv",
    index=False
)

customer_metrics.to_csv(
    "../PowerBI_Dashboard/customer_metrics.csv",
    index=False
)
